# %%
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
import matplotlib
sns.set()

# %%
dataset = pd.read_csv("cvlibd/server/data/volume-render/rho_max.csv")

# %%
dataset[dataset.rho.notnull()].rho.hist()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("cvlibd/server/data/volume-render/v02_splash.csv")

df.columns

df.insert(2, "x_axis", x_axis)

# %%
df
# Out:
#     timestep    y  x_axis    x    z
# 0          1  246  0.1141    0    0
# 1          2  246  0.2286    0    0
# 2          3  246  0.4566    0    0
# 3          4  246  0.6817    0    0
# 4          5  246  0.8948    0    0
# 5          6  246  1.0487    0    0
# 6          7  246  1.2244  137  150
# 7          8  245  1.3306  137  150
# 8          9  245  1.5159  133  151
# 9         10  244  1.6898  130  152
# 10        11  244  1.7954  128  151
# 11        12  245  1.8741  127  150
# 12        13  244  1.9021  127  150
# 13        14  243  1.9749  127  149
# 14        15  243  2.0550  126  149
# 15        16  243  2.2010  124  154
# 16        17  244  2.3341  123  149
# 17        18  244  2.4095  122  151
# 18        19  244  2.5659  124  159
# 19        20  245  2.6103  123  146
# 20        21  242  2.7970  137  154
# 21        22  242  2.8245  135  154
# 22        23  239  2.9693  133  154
# 23        24  239  3.0068  132  155
# 24        25  228  3.3719  126  160
# 25        26  228  3.5332  124  159
# 26        27  229  3.6069  123  159
# 27        28  231  3.7669  117  163
# 28        29  230  3.9067  144  152
# 29        30  227  4.1035  144  152
# 30        31  230  4.4262  145  152
# 31        32  244  4.6984  116  153
# 32        33  247  4.8989    0    0
# 33        34  247  4.9275    0    0
# 34        35  247  4.9577    0    0
# 35        36  247  4.9978    0    0

# %%
fontsize = 16

sns.set(rc={'figure.figsize':(9.7,7.27)})
df.plot(x="x_axis", y=["x", "z"], fontsize=fontsize)
plt.legend(["Y", "Z"], loc="best", fontsize=fontsize)
plt.title("Range of water splash over time in Y and Z dimension", fontsize=fontsize + 2)
plt.xlabel("Time (s)", fontsize=fontsize)
plt.ylabel("Maximum height of water splash (m)", fontsize=fontsize)
plt.savefig("GIFS/zy_dimension")
plt.show()


# df.plot(x="x_axis", y=["y"])
# plt.legend(["X"], loc="best")
# plt.show()

df.plot(x="x_axis", y=["y"], fontsize=fontsize)
plt.legend(["X"], loc="best", fontsize=fontsize)
plt.title("Range of water splash over time in X dimension", fontsize=fontsize + 2)
plt.xlabel("Time (s)", fontsize=fontsize)
plt.ylabel("Maximum height of water splash (m)", fontsize=fontsize)
plt.savefig("GIFS/x_dimension")
plt.show()

# %%
tev = pd.read_csv("cvlibd/server/data/volume-render/tev.csv")
prs = pd.read_csv("cvlibd/server/data/volume-render/prs.csv")
v03 = pd.read_csv("cvlibd/server/data/volume-render/v03.csv")
combined = pd.concat([tev.tev, prs.prs, v03.v03, df.y ],axis=1)

# %%
sns.pairplot(combined)
# corr = combined.corr()
# sns.heatmap(corr)

# %%
plt.scatter(tev.tev, v03.v03)
plt.xlabel("Temperature")
plt.ylabel("Asteroid volume")
plt.show()

# %%
import os
files = os.listdir("data")

# %%
total = []
for i in files:
    if i != ".DS_Store":
        total.append(int(i.split("_")[3].replace(".vti", ""))/10000 )

total.sort()
print(total)
# Out:
# [0.1141, 0.2286, 0.4566, 0.6817, 0.8948, 1.0487, 1.2244, 1.3306, 1.5159, 1.6898, 1.7954, 1.8741, 1.9021, 1.9749, 2.055, 2.201, 2.3341, 2.4095, 2.5659, 2.6103, 2.797, 2.8245, 2.9693, 3.0068, 3.3719, 3.5332, 3.6069, 3.7669, 3.9067, 4.1035, 4.4262, 4.6984, 4.8989, 4.9275, 4.9577, 4.9978]
